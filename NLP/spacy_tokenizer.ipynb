# %%
# !pip install click
# !pip install spacy

# %%
import spacy

# %%
nlp=spacy.blank("en")
doc=nlp("This is a sentence.")
for token in doc:
    print(token)
# Out:
# This
# is
# a
# sentence
# .

# %%
doc[0]
# Out:
# This

# %%
token = doc[1]
token.text
# Out:
# 'is'

# %%
dir(token)
# Out:
# ['_',
#  '__bytes__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  'ancestors',
#  'check_flag',
#  'children',
#  'cluster',
#  'conjuncts',
#  'dep',
#  'dep_',
#  'doc',
#  'ent_id',
#  'ent_id_',
#  'ent_iob',
#  'ent_iob_',
#  'ent_kb_id',
#  'ent_kb_id_',
#  'ent_type',
#  'ent_type_',
#  'get_extension',
#  'has_dep',
#  'has_extension',
#  'has_head',
#  'has_morph',
#  'has_vector',
#  'head',
#  'i',
#  'idx',
#  'iob_strings',
#  'is_alpha',
#  'is_ancestor',
#  'is_ascii',
#  'is_bracket',
#  'is_currency',
#  'is_digit',
#  'is_left_punct',
#  'is_lower',
#  'is_oov',
# ...

# %%
doc = nlp("This is another sentence.")

# %%
token0 = doc[0]
token0
# Out:
# This

# %%
token0.is_alpha
# Out:
# True

# %%
token0.like_num
# Out:
# False

# %%
token3 = doc[3]
token3
# Out:
# sentence

# %%
token3.like_num
# Out:
# False

# %%
token3.is_currency
# Out:
# False
